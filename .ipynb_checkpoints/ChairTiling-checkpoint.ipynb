# %%
#imports go here

from sage.plot.polygon import Polygon
from sage.plot.colors import rainbow

# %%
def add_points (a, b):
    return

# Note: This returns a graphics object. To get the actual polygon object, you must index into the return value at [0].
def construct_chair_primitive_tile (origin, orientation, color) -> Polygon:
    primitive_points = [(0,0), (2,0), (2,1), (1,1), (1,2), (0,2)]
    tile = polygon([(origin[0] + orientation[0] * p[0], origin[1] + orientation[1] * p[1]) for p in primitive_points], 
                   rgbcolor=color, edgecolor='black', fill=true)
    return tile

# To show the individual subtiles, we need to plot them each, so we need one graphics polygon that has a list of 
# each of the primitive tiles. To know the scale of the next supertile, we only need to keep track of that 
# tile's size. So, to make an L_n supertile, we take in 
# 1) the size of the tile
# 2) the origin of the tile (i.e. which corner is oppposite the missing chunk)
# 3) the orientation of the tile (given as a tuple of (+/- 1, +/- 1))
# 4) color
def construct_chair_supertile (size, origin, orientation, color, graphic) -> Polygon:
    #Now, we can start to construct the supertile. We want to combine four of the L_(n-1) tile.
    if (size < 2):
        print(f"Invalid input size of {size}.")
        return
    if (size == 2):
        # This is our base case. We have a primitive tile, and we need to just plot it.
        return construct_chair_primitive_tile (origin, orientation, color)

    #We have a supertile with n>0. This means we must use recursion to plot the tile.
    newsize = size / 2

    graphic += construct_chair_supertile (newsize, origin, orientation, color, graphic)
    graphic += construct_chair_supertile (newsize,
                                (origin[0] + orientation[0] * newsize / 2, origin[1] + orientation[1] * newsize / 2),
                                orientation,
                                color,
                                graphic)
    graphic += construct_chair_supertile (newsize,
                                (origin[0] + orientation[0] * size, origin[1]),
                                (-1 * orientation[0], orientation[1]),
                                color,
                                graphic)
    graphic += construct_chair_supertile (newsize,
                                (origin[0], origin[1] + orientation[1] * size),
                                (orientation[0], -1 * orientation[1]),
                                color,
                                graphic)

    return graphic


def construct_chair_tiling (iterations):
    # rbow = rainbow(iterations)
    
    for i in range (iterations):
        g = plot((0,0))
        g = construct_chair_supertile (2 ** (1+i), (0,0), (1,1), 'white', g)
        show(g)

    return

# %%
Ln = construct_chair_tiling(4)
Ln
# Out:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 6 graphics primitives
# Graphics object consisting of 92 graphics primitives
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Ln = construct_chair_tiling(Integer(4))
#       2 Ln
#
# Cell In[23], line 56, in construct_chair_tiling(iterations)
#      54     g = plot((Integer(0),Integer(0)))
#      55     g = construct_chair_supertile (Integer(2) ** (Integer(1)+i), (Integer(0),Integer(0)), (Integer(1),Integer(1)), 'white', g)
# ---> 56     show(g)
#      58 return
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/repl/rich_output/pretty_print.py:343, in show(*args, **kwds)
#     341     args[0].show()
#     342     return
# --> 343 pretty_print(*args, **kwds)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/repl/rich_output/pretty_print.py:311, in pretty_print(*args, **kwds)
#     309     pass
#     310 elif len(args) == 1:
# --> 311     dm.display_immediately(*args, **kwds)
#     312 else:
#     313     SequencePrettyPrinter(*args, **kwds).pretty_print()
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/repl/rich_output/display_manager.py:842, in DisplayManager.display_immediately(self, obj, **rich_repr_kwds)
#     819 def display_immediately(self, obj, **rich_repr_kwds):
#     820     """
#     821     Show output without going back to the command line prompt.
#     822
#    (...)
#     840         1/2
#     841     """
# --> 842     plain_text, rich_output = self._rich_output_formatter(obj, rich_repr_kwds)
#     843     self._backend.display_immediately(plain_text, rich_output)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/repl/rich_output/display_manager.py:631, in DisplayManager._rich_output_formatter(self, obj, rich_repr_kwds)
#     629 has_rich_repr = isinstance(obj, SageObject) and hasattr(obj, '_rich_repr_')
#     630 if has_rich_repr:
# --> 631     rich_output = self._call_rich_repr(obj, rich_repr_kwds)
#     632 if isinstance(rich_output, OutputPlainText):
#     633     plain_text = rich_output
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/repl/rich_output/display_manager.py:591, in DisplayManager._call_rich_repr(self, obj, rich_repr_kwds)
#     589     return obj._rich_repr_(self, **rich_repr_kwds)
#     590 try:
# --> 591     return obj._rich_repr_(self)
#     592 except NotImplementedError:
#     593     # don't warn on NotImplementedErrors
#     594     return None
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/plot/graphics.py:1012, in Graphics._rich_repr_(self, display_manager, **kwds)
#    1010 for file_ext, output_container in preferred:
#    1011     if output_container in display_manager.supported_output():
# -> 1012         return display_manager.graphics_from_save(
#    1013             self.save, kwds, file_ext, output_container)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/repl/rich_output/display_manager.py:721, in DisplayManager.graphics_from_save(self, save_function, save_kwds, file_extension, output_container, figsize, dpi)
#     719 if dpi is not None:
#     720     kwds['dpi'] = dpi
# --> 721 save_function(filename, **kwds)
#     722 from sage.repl.rich_output.buffer import OutputBuffer
#     723 buf = OutputBuffer.from_file(filename)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/misc/decorators.py:414, in suboptions.__call__.<locals>.wrapper(*args, **kwds)
#     410         del kwds[key]
#     412 kwds[self.name + "options"] = suboptions
# --> 414 return func(*args, **kwds)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/plot/graphics.py:3371, in Graphics.save(self, filename, **kwds)
#    3368 from matplotlib import rcParams
#    3369 rc_backup = (rcParams['ps.useafm'], rcParams['pdf.use14corefonts'],
#    3370              rcParams['text.usetex'])  # save the rcParams
# -> 3371 figure = self.matplotlib(**options)
#    3372 # You can output in PNG, PS, EPS, PDF, PGF, or SVG format, depending
#    3373 # on the file extension.
#    3374 # PGF is handled by a different backend
#    3375 if ext == '.pgf':
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/plot/graphics.py:2826, in Graphics.matplotlib(self, filename, xmin, xmax, ymin, ymax, figsize, figure, sub, axes, axes_labels, axes_labels_size, flip_x, flip_y, fontsize, frame, verify, aspect_ratio, gridlines, gridlinesstyle, vgridlinesstyle, hgridlinesstyle, show_legend, legend_options, axes_pad, ticks_integer, tick_formatter, ticks, title, title_pos, base, scale, stylesheet, typeset)
#    2824         pass
#    2825 g.set_options(opts)
# -> 2826 g._render_on_subplot(subplot)
#    2827 if hasattr(g, '_bbox_extra_artists'):
#    2828     self._bbox_extra_artists.extend(g._bbox_extra_artists)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/sage/plot/polygon.py:281, in Polygon._render_on_subplot(self, subplot)
#     279 p.set_label(options['legend_label'])
#     280 p.set_zorder(z)
# --> 281 subplot.add_patch(p)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/matplotlib/axes/_base.py:2446, in _AxesBase.add_patch(self, p)
#    2444 if p.get_clip_path() is None:
#    2445     p.set_clip_path(self.patch)
# -> 2446 self._update_patch_limits(p)
#    2447 self._children.append(p)
#    2448 p._remove_method = self._children.remove
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/matplotlib/axes/_base.py:2477, in _AxesBase._update_patch_limits(self, patch)
#    2474 if len(vertices):
#    2475     vertices = np.vstack(vertices)
# -> 2477 patch_trf = patch.get_transform()
#    2478 updatex, updatey = patch_trf.contains_branch_seperately(self.transData)
#    2479 if not (updatex or updatey):
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/matplotlib/patches.py:309, in Patch.get_transform(self)
#     307 def get_transform(self):
#     308     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 309     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/matplotlib/patches.py:327, in Patch.get_patch_transform(self)
#     318 def get_patch_transform(self):
#     319     """
#     320     Return the `~.transforms.Transform` instance mapping patch coordinates
#     321     to data coordinates.
#    (...)
#     325     transform which scales the coordinates (the patch coordinate) by 5.
#     326     """
# --> 327     return transforms.IdentityTransform()
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/matplotlib/transforms.py:1770, in AffineBase.__init__(self, *args, **kwargs)
#    1769 def __init__(self, *args, **kwargs):
# -> 1770     super().__init__(*args, **kwargs)
#    1771     self._inverted = None
#
# File ~/miniforge3/envs/sage/lib/python3.11/site-packages/matplotlib/transforms.py:110, in TransformNode.__init__(self, shorthand_name)
#     104 pass_through = False
#     105 """
#     106 If pass_through is True, all ancestors will always be
#     107 invalidated, even if 'self' is already invalid.
#     108 """
# --> 110 def __init__(self, shorthand_name=None):
#     111     """
#     112     Parameters
#     113     ----------
#    (...)
#     117         ``str(transform)`` when DEBUG=True.
#     118     """
#     119     self._parents = {}
#
# File signals.pyx:355, in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
# Stays the same
points1 = [(0,0), (2,0), (2,1), (1,1), (1,2), (0,2)]

# Right shift by 2*tile length and horizontal reflection
rtile_origin = (4,0)
points2 = [(rtile_origin[0] - po[0], rtile_origin[1] + po[1]) for po in points1]

# Upwards shift by 2*tile length and vertical reflection
ltile_origin = (0,4)
points3 = [(ltile_origin[0] + po[0], ltile_origin[1] - po[1]) for po in points1]

# Right and upwards shift by 1/2 * tile length
utile_origin = (1,1)
points4 = [(utile_origin[0] + po[0], utile_origin[1] + po[1]) for po in points1]

p1 = polygon(points1, edgecolor='black')
p = p1

p2 = polygon(points2, edgecolor='black')
p += p2

p3 = polygon(points3, edgecolor='black')
p += p3

p4 = polygon(points4, edgecolor='black')
p += p4

show(p)
